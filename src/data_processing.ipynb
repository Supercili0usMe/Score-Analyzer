# %%
from openpyxl import load_workbook
import os
import pandas as pd

# %% [markdown]
# ### Скрипт №1:
# 1. Открываем существующий Excel
# 2. Считываем организацию
# 3. Считываем имя учащегося
# 4. Считываем класс
# 5. Считываем период обучения

# %%
data = load_workbook(r"D:\Project\Score-Analyzer\data\Отметки_1.xlsx")
work_sheet = data.active
info = {}

for row in range(1, 8, 2):
    key = work_sheet[f"A{row}"].value[:-1]
    value = work_sheet[f"A{row+1}"].value
    info[key] = value

print(info)
# Out:
# {'Организация': 'ГБОУ лицей №64', 'Обучающийся': 'Швайко Иван Сергеевич', 'Класс': '9 б', 'Период': 'II четверть'}

# %%
df = pd.read_excel(r"D:\Project\Score-Analyzer\data\Отметки_1.xlsx", skiprows=[i for i in range(0, 9)])
df
# Out:
#                                              Предметы 06.11.2024 07.11.2024  \
# 0                                             Алгебра          •        NaN
# 1                                            Биология          •        NaN
# 2                            Вероятность и статистика        NaN          •
# 3                                           География          5        NaN
# 4                                           Геометрия          •        NaN
# 5                       Иностранный язык (английский)        NaN          •
# 6                                         Информатика        NaN        NaN
# 7                                             История          •        NaN
# 8                                          Литература          5          •
# 9                                      Обществознание          •        NaN
# 10                Основы безопасности и защиты Родины        NaN        NaN
# ...

# %% [markdown]
# ### Скрипт №2:
# 1. Создать массив значений и предметов
# 2. Проверка входного листа (пустой, отсутствует)

# %%
data = load_workbook(r"D:\Project\Score-Analyzer\data\Отметки_1.xlsx")
work_sheet = data.active

subjects = {}
for c, i in enumerate(work_sheet.rows):
    # Проверяем только начиная с 9 строки
    if c > 9:
        # Берем значение первого столбца
        value = i[0].value
        if value:
            subjects[c+1] = value
        else:
            break

print(len(subjects))
print(subjects)
# Out:
# 16
# {11: 'Алгебра', 12: 'Биология', 13: 'Вероятность и статистика', 14: 'География', 15: 'Геометрия', 16: 'Иностранный язык (английский)', 17: 'Информатика', 18: 'История', 19: 'Литература', 20: 'Обществознание', 21: 'Основы безопасности и защиты Родины', 22: 'Русский язык', 23: 'Труд (технология)', 24: 'Физика', 25: 'Физическая культура', 26: 'Химия'}

# %%
def extract_subjects(worksheet, start_row=11, column_index=0) -> dict:
    subjects = {}
    for idx, row in enumerate(list(worksheet.rows)[start_row-1:]):
        if row[column_index].value is None:
            break
        subjects[idx + 1] = row[column_index].value
    return subjects


data = load_workbook(r"D:\Project\Score-Analyzer\data\Отметки_3.xlsx")
work_sheet = data.active
subjects = extract_subjects(work_sheet)
print(len(subjects))
print(subjects)
# Out:
# 11
# {1: 'Изобразительное искусство', 2: 'Иностранный язык (английский)', 3: 'Литературное чтение', 4: 'Математика', 5: 'Музыка', 6: 'Окружающий мир', 7: 'Основы православной культуры', 8: 'Основы светской этики', 9: 'Русский язык', 10: 'Труд (технология)', 11: 'Физическая культура'}

# %% [markdown]
# ### Скрипт №3:

# %% [markdown]
# 1. Собрать оценки по предметам по датам
# 2. Формат вывода следующий:
# ```json
# {
#     "Изобразительное искусство":
#     [
#         {"Дата": "23.09.2024", "Отметка": "4"},
#         {"Дата": "07.10.2024", "Отметка": "5"},
#         {"Дата": "21.10.2024", "Отметка": "5"},
#         {"Дата": "21.10.2024", "Отметка": "4"},
#         ...
#     ],
#     "Иностранный язык (английский)":
#     [
#         ...
#     ],
#     ...
# }
# ```
# 3. Проверка входных данных: оценки должны быть только цифрами (убрать символы: '•', 'Н', '!')
# 4. Если больше 1 оценки за день, то записываем их рядом

# %%
# Создаём словарь из предметов
marks = {subj: [] for subj in subjects.values()}

# Указываем параметры
start_row = 10
start_column = 2

# Проходимся по колонкам
for value in work_sheet.iter_cols(min_row=start_row, max_row=start_row+len(subjects.values()), min_col=start_column, values_only=True):
    # Забираем дату из первой строки
    date = value[0]
    if date == "Итог:": break
    # Проходимся по остальным строкам
    for subj_id, mark in enumerate(value[1:]):
        if mark:
            for ch in mark:
                if ch.isdigit():
                    marks[subjects[subj_id+1]].append({"Дата": date, "Отметка": ch})

from pprint import pprint
pprint(marks)
# Out:
# {'Изобразительное искусство': [{'Дата': '23.09.2024', 'Отметка': '4'},
#                                {'Дата': '07.10.2024', 'Отметка': '5'},
#                                {'Дата': '21.10.2024', 'Отметка': '5'},
#                                {'Дата': '11.11.2024', 'Отметка': '4'},
#                                {'Дата': '18.11.2024', 'Отметка': '5'},
#                                {'Дата': '25.11.2024', 'Отметка': '4'},
#                                {'Дата': '02.12.2024', 'Отметка': '5'},
#                                {'Дата': '09.12.2024', 'Отметка': '5'}],
#  'Иностранный язык (английский)': [{'Дата': '18.09.2024', 'Отметка': '3'},
#                                    {'Дата': '25.09.2024', 'Отметка': '4'},
#                                    {'Дата': '30.09.2024', 'Отметка': '4'},
#                                    {'Дата': '09.10.2024', 'Отметка': '4'},
#                                    {'Дата': '11.11.2024', 'Отметка': '3'},
# ...

# %% [markdown]
# ### Скрипт №4:

# %% [markdown]
# 1. Преобразование получаемого словаря в 2 значения: <список_дат>, <список_оценок>
# 2. Формат ввода: словарь выше, название предмета
# 3. Формат вывода следующий:
# ```json
# subject = "Изобразительное искусство"
# dates = ["23.09.2024", "07.10.2024", "21.10.2024", "21.10.2024", ...]
# marks = ["4", "5", "5", "4"]
# ```
# 4. Не возвращаем уникальные значения, а полные (для подсчета среднего балла)

# %%
# Определяем предмет, который будем выбирать
subject = "Русский язык"

# Выбираем данные, только этого предмета
dates, grades = [], []
for info in marks[subject]:
    dates.append(info["Дата"])
    grades.append(info["Отметка"])
print(dates)
print(grades)
# Out:
# ['10.09.2024', '24.09.2024', '01.10.2024', '15.10.2024', '22.10.2024', '07.11.2024', '12.11.2024', '12.11.2024', '15.11.2024', '20.11.2024', '22.11.2024', '26.11.2024', '28.11.2024', '29.11.2024', '06.12.2024', '12.12.2024', '12.12.2024']
# ['4', '4', '4', '3', '4', '4', '4', '4', '4', '4', '4', '4', '4', '3', '3', '3', '3']
